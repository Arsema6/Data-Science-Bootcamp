# %% [markdown]
# <a href="https://colab.research.google.com/github/Arsema6/Data-Science-Bootcamp/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. What is the difference between a list, a dictionary, and a NumPy array? Give one example of each.
import numpy as np
li = [1,2,3,4]
d = {'A':2, 'B': 3,'C':3}
nump = np.array((1,2,3))
print("List=",li)
print("Dictionary =",d)
print("num = ",nump)

#2.Given the list [10, 15, 20, 25, 30], write a function that returns the square of only even numbers.
def even_square(nums):
  res = []
  for num in nums:
    if num % 2 == 0:
      res.append(num**2)
  return res

print(even_square([10, 15, 20, 25, 30]))

#3. What does the following code output, and why?
x = [1,2,3]
y = x
y.append(4)
print(x)
#4.What does .shape and .describe() tell you about a pandas DataFrame? Show using an example.
import pandas as pd

data = {'name': ['Alice', 'Bob', 'Charlie'],
        'age': [25, 30, 28]}
df = pd.DataFrame(data)

print(df.shape)  # Output: (3, 2)
                 # This means the DataFrame has 3 rows and 2 columns.
print(df.describe()) """Output:
             age
count   3.000000
mean   27.666667
std     2.516611
min    25.000000
25%    26.500000
50%    28.000000
75%    29.000000
max    30.000000"""

"""5. Load this CSV: airtravel.csv
Print the first 5 rows
What do you notice about the data?"""

import pandas as pd

df = pd.read_csv("airtravel.csv")

print(df.head(5))

"""6.Load the CSV from Q5 and find:
  The month with the highest total passengers
  The month with the lowest in 1958"""

import pandas as pd

df = pd.read_csv("airtravel (1).csv")

max_passengers_month = df.loc[df['# of Passengers'].idxmax(), 'Month']

print("Month with highest total passengers:", max_passengers_month)

df_1958 = df[df['Month'].str.endswith('58')]
min_passengers_month_1958 = df_1958.loc[df_1958['# of Passengers'].idxmin(), 'Month']

print("Month with lowest passengers in 1958:", min_passengers_month_1958)

#7. What does the .groupby() function do in pandas? Show an example using dummy data.

import pandas as pd

# Create dummy sales data
data = {'Course': ['Signal','Circuit', 'Computational', 'EMF', 'Linear Algebra'],
        'Grade': ['A', 'B', 'B', 'A',  'B'],
        'credit hour': [3, 4, 4, 3, 3]}

df = pd.DataFrame(data)

point = df.groupby('Grade')['credit hour'].sum()

print(point)# A has 6 credit hours     B has 11 credit hours
"""8. Load the Titanic dataset from seaborn and:

  Count how many missing values are in each column"""

import seaborn as sns
import pandas as pd
titanic_df = sns.load_dataset('titanic')# Load the Titanic dataset
missing_values_count = titanic_df.isnull().sum()

print(missing_values_count)

"""9.  Use df["Age"].hist() to visualize the age distribution.
What shape do you see

What might be the reason for the skew?"""

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Visualize age distribution
titanic_df["age"].hist()
plt.title("Age Distribution of Titanic Passengers")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

"""10. What does it mean if a column has a high standard deviation?

  Create a list or column that has a low and a high std. dev, and compare.  """

import numpy as np

a = [9, 10, 10, 11, 10]  #low_std
mean = np.mean(a)
std_dev1 = np.std(a)
b = [1, 5, 20, 50, 100]  #high_std
mean = np.mean(b)
std_dev2 = np.std(high_std)
print(std_dev1)
print(std_dev2)

#11.What are some real-world problems where missing data might affect results? Give 2 examples.

# %% [markdown]
# 1. List
# *   Is a collection of data with the same data type.
# *   Elements can be easily accessed using their index.
#
#
# Dictionary:
# *   Collection of key-value pairs.
# *   accessed using key.
#
# NumPy array:
#
# *   A grid of values all of the same type.
# *   Elements can be easily accessed using their index.
#
#
# 2.even_square: This function takes a list of numbers and returns the square of only even numbers.
#
# Argument: A list of numbers called nums.
#
# for-loop: if num is even we append the square of num into res.
#
#
#
# 3.x = [1, 2, 3] #creates a list object and assigns it to variable x.
#
# y = x # both x and y now reference the same list in memory.
#
# y.append(4) #modifies the list by adding 4 to it.
#
# Since both x and y refer to the same list, printing x will show the modified list [1, 2, 3, 4].
#
#
# 4.**.shape:** It returns the dimensions of the DataFrame as a tuple (number of rows, number of columns).
#
# **.describe():** It generates descriptive statistics of the numerical columns in the DataFrame (like count, mean, standard deviation, min, max, etc.).
#
# 5.import pandas as pd: This line imports the pandas library,This allows to use pandas functions and classes using the pd prefix.
#
# df = pd.read_csv("airtravel (1).csv"): This line reads a CSV (Comma-Separated Values) file named "airtravel (1).csv" and stores its contents in a pandas DataFrame named df.
#
# print(df.head()): This line displays the first 5 rows of the DataFrame df. The head() function is way to get a quick overview of your data after loading it.
#
# I noticed from this data:
#
# Travel over time: The data shows how air travel changes throughout the year. We can see if more people travel in certain months compared to others.
#
# Busy and slow times: We might find that some months have a lot of passengers (busy times), while others have fewer (slow times). This could be because of holidays, seasons, or other reasons.
#
# Future travel: By looking at past travel patterns, we might be able to guess how many people will travel in the future. This is called forecasting.
#
# 6.df['# of Passengers'].idxmax(): This line finds the index (row number) of the row containing the maximum value in the '# of Passengers' column. df.loc[...]: This line uses the index obtained in the previous step to locate the corresponding row in the DataFrame and then extracts the value from the 'Month' column. Step 3: Find the month with the lowest passengers in 1958
#
# df[df['Month'].str.endswith('58')]: This line filters the DataFrame to include only rows where the 'Month' value ends with '58', representing the year 1958. df_1958['# of Passengers'].idxmin(): This line finds the index (row number) of the row containing the minimum value in the '# of Passengers' column within the filtered data for 1958. df_1958.loc[...]: This line uses the index obtained in the previous step to locate the corresponding row in the filtered DataFrame and then extracts the value from the 'Month' column.
#
# 7..groupby() :
#
# - used to split a DataFrame into groups based on the values in one or more columns.
#
# - allows you to perform calculations and analysis on each group separately.
#
# 8.survived         0
#
# pclass           0
#
# sex              0
#
# age            177
#
# sibsp            0
#
# parch            0
#
# fare             0
#
# embarked         2
#
# class            0
#
# who              0
#
# adult_male       0
#
# deck           688
#
# embark_town      2
#
# alive            0
#
# alone            0
#
# dtype: int64
#
# 10.High deviation: a measure of the amount of variation of the values of a variable about its mean which indicates that the values are spread out over a wider range.
#
# - if a column has a high standard deviation, It means that the data points in a column are spread out widely from the mean (average).
#
# 11.Missing data can significantly impact results in various real-world scenarios, leading to biased or inaccurate conclusions. Two examples include:
#
# Survey Research: If certain groups of people consistently skip specific questions, the survey results may not accurately represent the population being studied. For example, if younger participants are more likely to avoid questions about income, the analysis might misrepresent the income distribution of the population. This type of missing data can introduce bias, as the missing data is not randomly distributed and is related to the characteristics of the people who chose to skip the questions.
#
#
# Clinical Trials: In clinical trials, if patients drop out of the study before completing the treatment or follow-up, the results may be skewed. For instance, if patients with severe side effects are more likely to withdraw, the analysis might overestimate the efficacy of the treatment. This missing data can lead to biased estimates of treatment effectiveness and potentially harmful conclusions. In both examples, the missing data violates the assumption of random sampling, leading to potential biases in the analysis and making the conclusions unreliable.
